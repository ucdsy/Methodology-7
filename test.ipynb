# %%
import sys
import subprocess
import os
from src import etl
import json
sys.path.insert(0, 'src')
from src import eda

# %%
eda_config=json.load(open('config/eda-params.json'))

# %%
eda.generate_stats('test', **eda_config)

# %%
parent_dir=os.getcwd()

# %%
parent_dir
# Out:
# 'c:\\Users\\sisi\\Desktop\\Project-Structure'
